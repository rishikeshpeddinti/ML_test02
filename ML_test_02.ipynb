# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("trainData.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df2=pd.read_csv("testData.csv")
df2
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df2.shape
# Out:
# (367, 12)

# %%
df2.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 362    False   False    False       False      False          False
# 363    False   False    False       False      False          False
# 364    False   False    False       False      False          False
# 365    False   False    False       False      False          False
# 366    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False       False             False
# ...

# %%
a=(df).append(df2)
a
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0               5849                0.0             1.0          0
# 1               4583             1508.0             1.0          1
# 2               3000                0.0             1.0          0
# 3               2583             2358.0             1.0          0
# 4               6000                0.0             1.0          0
# ..               ...                ...             ...        ...
# 362             4009             1777.0             1.0         3+
# 363             4158              709.0             1.0          0
# 364             3250             1993.0             NaN          0
# 365             5000             2393.0             1.0          0
# 366             9200                0.0             1.0          0
#
#         Education Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# 0        Graduate   Male         NaN             360.0  LP001002           Y
# ...

# %%
a.shape
# Out:
# (981, 13)

# %%
a.fillna
# Out:
# <bound method DataFrame.fillna of      ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0               5849                0.0             1.0          0
# 1               4583             1508.0             1.0          1
# 2               3000                0.0             1.0          0
# 3               2583             2358.0             1.0          0
# 4               6000                0.0             1.0          0
# ..               ...                ...             ...        ...
# 362             4009             1777.0             1.0         3+
# 363             4158              709.0             1.0          0
# 364             3250             1993.0             NaN          0
# 365             5000             2393.0             1.0          0
# 366             9200                0.0             1.0          0
#
#         Education Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# ...

# %%
a.dropna()
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 1               4583             1508.0             1.0          1
# 2               3000                0.0             1.0          0
# 3               2583             2358.0             1.0          0
# 4               6000                0.0             1.0          0
# 5               5417             4196.0             1.0          2
# ..               ...                ...             ...        ...
# 609             2900                0.0             1.0          0
# 610             4106                0.0             1.0         3+
# 611             8072              240.0             1.0          1
# 612             7583                0.0             1.0          2
# 613             4583                0.0             0.0          0
#
#         Education  Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# 1        Graduate    Male       128.0             360.0  LP001003           N
# ...

# %%
from sklearn.preprocessing import LabelEncoder
num = LabelEncoder()
a["Gender"] = num.fit_transform(a["Gender"].astype(str))
a["Gender"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 362    1
# 363    1
# 364    1
# 365    1
# 366    1
# Name: Gender, Length: 981, dtype: int32

# %%
a["Married"] = num.fit_transform(a["Married"].astype(str))
a["Married"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 362    1
# 363    1
# 364    0
# 365    1
# 366    0
# Name: Married, Length: 981, dtype: int32

# %%
a["Dependents"] = num.fit_transform(a["Dependents"].astype(str))
a["Dependents"]
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 362    3
# 363    0
# 364    0
# 365    0
# 366    0
# Name: Dependents, Length: 981, dtype: int32

# %%
a["Education"] = num.fit_transform(a["Education"].astype(str))
a["Education"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 362    1
# 363    0
# 364    0
# 365    0
# 366    0
# Name: Education, Length: 981, dtype: int32

# %%
a["Self_Employed"] = num.fit_transform(a["Self_Employed"].astype(str))
a["Self_Employed"]
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 362    1
# 363    0
# 364    0
# 365    0
# 366    1
# Name: Self_Employed, Length: 981, dtype: int32

# %%
a["Property_Area"] = num.fit_transform(a["Property_Area"].astype(str))
a["Property_Area"]
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 362    2
# 363    2
# 364    1
# 365    0
# 366    0
# Name: Property_Area, Length: 981, dtype: int32

# %%
a["Gender"].value_counts()
# Out:
# 1    775
# 0    182
# 2     24
# Name: Gender, dtype: int64

# %%
a["Married"].value_counts()
# Out:
# 1    631
# 0    347
# 2      3
# Name: Married, dtype: int64

# %%
a["Dependents"].value_counts()
# Out:
# 0    545
# 2    160
# 1    160
# 3     91
# 4     25
# Name: Dependents, dtype: int64

# %%
a["Education"].value_counts()
# Out:
# 0    763
# 1    218
# Name: Education, dtype: int64

# %%
a["Self_Employed"].value_counts()
# Out:
# 0    807
# 1    119
# 2     55
# Name: Self_Employed, dtype: int64

# %%
a["Property_Area"].value_counts()
# Out:
# 1    349
# 2    342
# 0    290
# Name: Property_Area, dtype: int64

# %%
import random as r
import numpy as np
b=a.copy()
b['LoanAmount'].fillna((b['LoanAmount'].median()),inplace=True)
b['Dependents'].fillna((b['Dependents'].median()),inplace=True)
